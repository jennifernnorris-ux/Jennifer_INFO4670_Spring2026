# %% [markdown]
# <a href="https://colab.research.google.com/github/jennifernnorris-ux/Jennifer_INFO4670_Spring2026/blob/main/Assignment_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Data Quality Check

# %% [markdown]
# **1.1 Using Python (pandas, matplotlib, or seaborn), load and inspect the Assignment 2 dataset.**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9814ba57-34f4-4e60-aa3e-5f1af51fa2a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9814ba57-34f4-4e60-aa3e-5f1af51fa2a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("Assignment 2 dataset.csv")

# %%
df.head()
# Out:
#    Column 1        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0  12-27-2015          1.33      64236.62  1036.74   54454.85
# 1         1  12-20-2015          1.35      54876.98   674.28   44638.81
# 2         2  12-13-2015          0.93     118220.22   794.70  109149.67
# 3         3   12-6-2015          1.08      78992.15  1132.00   71976.41
# 4         4  11-29-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18254 entries, 0 to 18253
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Column 1      18254 non-null  int64
#  1   Date          18254 non-null  object
#  2   AveragePrice  18254 non-null  float64
#  3   Total Volume  18253 non-null  float64
#  4   4046          18252 non-null  float64
#  5   4225          18253 non-null  float64
#  6   4770          18253 non-null  float64
#  7   Total Bags    18253 non-null  float64
#  8   Small Bags    18252 non-null  float64
#  9   Large Bags    18252 non-null  float64
#  10  XLarge Bags   18253 non-null  float64
#  11  type          18253 non-null  object
#  12  year          18254 non-null  int64
#  13  region        18254 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# **Write code to explore the data distribution (e.g., region, type, year) and check whether there is any bias. Provide both the code and your interpretation.**

# %%
df["region"].value_counts()
# Out:
# region
# WestTexNewMexico       340
# Albany                 338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# Atlanta                338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# BuffaloRochester       338
# LasVegas               338
# LosAngeles             338
# MiamiFtLauderdale      338
# Louisville             338
# Nashville              338
# NewOrleansMobile       338
# NewYork                338
# Midsouth               338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# ...

# %% [markdown]
# When searching for bias in the regions, I found that West Tex New Mexico has 340 entries while the rest has 338. This is an outlier in the dataset, but does not present a strong region bias, only slight.

# %%
df["type"].value_counts()
# Out:
# type
# organic         9127
# conventional    9126
# Name: count, dtype: int64

# %% [markdown]
# I checked the distribution of avocado types in the dataset. The number of organic and conventional avocados are similar, which indicates little to no bias in avocado type representation.

# %%
df["year"].value_counts()
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1300
# 1904       1
# Name: count, dtype: int64

# %% [markdown]
# I examined the distribution of data across years. The years 2017, 2016, and 2015 contain more records than others, which indicates a temporal bias in the dataset. The data is not evenly distributed across all years.

# %% [markdown]
# **1.2 Write Python code to check for duplicate rows and missing values in the dataset. Show the number of duplicates and missing values for each column. Then, explain (in comments or markdown) how you would handle these issues (e.g., drop, impute, or replace).**

# %%
df[df.duplicated()]
# Out:
#        Column 1       Date  AveragePrice  Total Volume     4046     4225  \
# 18249        10  1-14-2018          1.93      16205.22  1527.63  2981.04
# 18253         7   2-4-2018          1.63      17074.83  2046.96  1529.20
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18249  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18253    0.00    13498.67    13066.82      431.85          0.0  organic  2018
#
#                  region
# 18249  WestTexNewMexico
# 18253  WestTexNewMexico

# %% [markdown]
# This dataset contains 2 duplicate rows. Duplicate records should be dropped to prevent skewing the analysis.

# %%
df.isnull().sum()
# Out:
# Column 1        0
# Date            0
# AveragePrice    0
# Total Volume    1
# 4046            2
# 4225            1
# 4770            1
# Total Bags      1
# Small Bags      2
# Large Bags      2
# XLarge Bags     1
# type            1
# year            0
# region          0
# dtype: int64

# %% [markdown]
# This dataset contains a few instances of missing data. Numerical data such as 4046, 4225, 4770, Total volume, small bags, large bags, and XLarge Bags should be imputed with their median value to preserve the dataset size while minimizing distortion. Categorical values such as type should be replaced with a placeholder or imputed with the mode.

# %% [markdown]
# **1.3 Use Python code to print the number of rows and columns in the dataset (e.g., with df.shape). Based on the dataset size, explain (briefly) whether you think the dataset is sufficient for training a machine learning model.**

# %%
df.shape
# Out:
# (18254, 14)

# %% [markdown]
# The dataset contains over 18,000 rows and multiple relevant features, which provides a substantial amount of data for training a machine learning model. This size is generally sufficient to identify patterns and relationships in the data without severe risk of overfitting.

# %% [markdown]
# #2. Data Cleaning and Preprocessing

# %% [markdown]
# **2.1 Remove the first column or “Column 1” from the dataset. Treat the ‘year’ variable as nominal.**

# %%
df = df.drop(columns=["Column 1"])

# %%
df["year"] = df["year"].astype("category")

# %% [markdown]
# **2.2 Check for duplicate values and remove them.**

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **2.3 Check for missing values. If a data record (row) only has a few missing values, replace the missing values with the median of the column feature in that specific “Region” variable. If most column values in a data record are missing, remove the data record.**

# %%
df = df.copy()

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    1
# 4046            2
# 4225            1
# 4770            1
# Total Bags      1
# Small Bags      2
# Large Bags      2
# XLarge Bags     1
# type            1
# year            0
# region          0
# dtype: int64

# %%
bag_columns = ["Total Volume", "4046", "4225", "4770", "Total Bags", "Small Bags", "Large Bags", "XLarge Bags"]

for col in bag_columns:
    df[col] = df[col].fillna(
        df.groupby("region")[col].transform("median")
    )

# %%
df["type"] = df["type"].fillna(
    df.groupby("region")["type"].transform(lambda x: x.mode()[0])
)

# %%
df[["Total Volume", "4046", "4225", "4770", "Total Bags", "Small Bags", "Large Bags", "XLarge Bags", "type"]].isnull().sum()
# Out:
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# dtype: int64

# %% [markdown]
# **2.4 Find the correlation between the variables and describe how the correlated values among the variables impact the model accuracy.**

# %%
numeric_df = df.select_dtypes(include=["number"])

# %%
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192770 -0.208327 -0.172948 -0.179462
# Total Volume     -0.192770      1.000000  0.977863  0.974181  0.872203
# 4046             -0.208327      0.977863  1.000000  0.926110  0.833390
# 4225             -0.172948      0.974181  0.926110  1.000000  0.887856
# 4770             -0.179462      0.872203  0.833390  0.887856  1.000000
# Total Bags       -0.177106      0.963047  0.920057  0.905788  0.792316
# Small Bags       -0.174745      0.967238  0.925280  0.916032  0.802734
# Large Bags       -0.172958      0.880640  0.838646  0.810017  0.698473
# XLarge Bags      -0.117608      0.747159  0.699378  0.688811  0.679863
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags
# AveragePrice   -0.177106   -0.174745   -0.172958    -0.117608
# Total Volume    0.963047    0.967238    0.880640     0.747159
# 4046            0.920057    0.925280    0.838646     0.699378
# ...

# %% [markdown]
# Strongly correlated values are those that are above 0.7 or below -0.7. Several numeric features show strong positive correlations, particularly among bag-related variables and total volume. These correlations suggest redundancy in the data, which can reduce model accuracy by increasing overfitting. Reducing or combining correlated features can improve model performance.

# %% [markdown]
# #3. Exploratory Data Analysis (EDA)

# %% [markdown]
# **3.1 Describe the variables**
# - **Describe all variables in the dataset.**
# - **For continuous variables: report *range (min, max), mean, median, and distribution.***
# - **For categorical variables: list unique values.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18252 entries, 0 to 18252
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18252 non-null  object
#  1   AveragePrice  18252 non-null  float64
#  2   Total Volume  18252 non-null  float64
#  3   4046          18252 non-null  float64
#  4   4225          18252 non-null  float64
#  5   4770          18252 non-null  float64
#  6   Total Bags    18252 non-null  float64
#  7   Small Bags    18252 non-null  float64
#  8   Large Bags    18252 non-null  float64
#  9   XLarge Bags   18252 non-null  float64
#  10  type          18252 non-null  object
#  11  year          18252 non-null  category
#  12  region        18252 non-null  object
# dtypes: category(1), float64(9), object(3)
# memory usage: 1.8+ MB

# %%
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
categorical_cols = df.select_dtypes(include=["object"]).columns

numeric_cols, categorical_cols
# Out:
# (Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#         'Small Bags', 'Large Bags', 'XLarge Bags'],
#        dtype='object'),
#  Index(['Date', 'type', 'region'], dtype='object'))

# %%
df[numeric_cols].describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18252.000000  1.825200e+04  1.825200e+04  1.825200e+04  1.825200e+04
# mean       1.406032  8.505220e+05  2.929755e+05  2.951086e+05  2.283613e+04
# std        0.402668  3.453275e+06  1.264888e+06  1.204027e+06  1.074556e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.084172e+04  8.544900e+02  3.008553e+03  0.000000e+00
# 50%        1.370000  1.073655e+05  8.646205e+03  2.905888e+04  1.849950e+02
# 75%        1.660000  4.329334e+05  1.110664e+05  1.500853e+05  6.239325e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags
# count  1.825200e+04  1.825200e+04  1.825200e+04   18252.000000
# mean   2.396045e+05  1.821716e+05  5.432955e+04    3105.915918
# std    9.861651e+05  7.461194e+05  2.439468e+05   17691.485283
# ...

# %%
for col in categorical_cols:
    print(f"{col}:")
    print(df[col].unique())
    print()
# Out:
# Date:
# ['12-27-2015' '12-20-2015' '12-13-2015' '12-6-2015' '11-29-2015'
#  '11-22-2015' '11-15-2015' '11-8-2015' '11-1-2015' '10-25-2015'
#  '10-18-2015' '10-11-2015' '10-4-2015' '9-27-2015' '9-20-2015' '9-13-2015'
#  '9-6-2015' '8-30-2015' '8-23-2015' '8-16-2015' '8-9-2015' '8-2-2015'
#  '7-26-2015' '7-19-2015' '7-12-2015' '7-5-2015' '6-28-2015' '6-21-2015'
#  '6-14-2015' '6-7-2015' '5-31-2015' '5-24-2015' '5-17-2015' '5-10-2015'
#  '5-3-2015' '4-26-2015' '4-19-2015' '4-12-2015' '4-5-2015' '3-29-2015'
#  '3-22-2015' '3-15-2015' '3-8-2015' '3-1-2015' '2-22-2015' '2-15-2015'
#  '2-8-2015' '2-1-2015' '1-25-2015' '1-18-2015' '1-11-2015' '1-4-2015'
#  '12-25-2016' '12-18-2016' '12-11-2016' '12-4-2016' '11-27-2016'
#  '11-20-2016' '11-13-2016' '11-6-2016' '10-30-2016' '10-23-2016'
#  '10-16-2016' '10-9-2016' '10-2-2016' '9-25-2016' '9-18-2016' '9-11-2016'
#  '9-4-2016' '8-28-2016' '8-21-2016' '8-14-2016' '8-7-2016' '7-31-2016'
# ...

# %% [markdown]
# The type variable has two categories: conventional and organic. The region variable contains multiple geographic regions.

# %% [markdown]
# **3.2 Inspect the earliest recorded date**
#
# -  **Find the earliest** `Date`.
# - **Check if there are avocado prices recorded from the earliest date up to 2010.**
# - **Comment: does the earliest data point look reasonable? Keep or remove?**

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"].min()
# Out:
# Timestamp('1904-01-21 00:00:00')

# %%
df[df["Date"].dt.year <= 2010].shape
# Out:
# (1, 13)

# %% [markdown]
# The earliest data point doesn't seem as reasonable because there is only one value before 2010, it should probably be removed

# %% [markdown]
# **3.3 Highest average price**
# - **Find the highest value in "AveragePrice".**
# - **Report which region it belongs to.**
# - **Describe how you obtained the result.**

# %%
df["AveragePrice"].max()
# Out:
# 3.25

# %%
df.loc[df["AveragePrice"].idxmax(), ["region", "AveragePrice"]]
# Out:
# region          SanFrancisco
# AveragePrice            3.25
# Name: 14125, dtype: object

# %% [markdown]
# I obtained the highest average price by using the .max() function on the AveragePrice column and then filtering the dataset to identify the corresponding region.

# %% [markdown]
# **3.4 Highest total volume**
# - **Find the highest total volume of avocados.**
# - **Report which region it belongs to.**
# - **Describe how you obtained the result.**

# %%
df["Total Volume"].max()
# Out:
# 62505646.52

# %%
df.loc[df["Total Volume"].idxmax(), ["region", "Total Volume"]]
# Out:
# region              TotalUS
# Total Volume    62505646.52
# Name: 9097, dtype: object

# %% [markdown]
# The highest total avocado volume was identified by calculating the maximum value in the Total Volume column and locating the associated region.
